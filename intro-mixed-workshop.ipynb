# %% [markdown]
# # Introduction to Mixed-effects Workshop

# %% [markdown]
# ## Multiple Within-subject Factors

# %% [markdown]
# ### Multilevel Conceptualisation

# %% [markdown]
# ## Within-subject and Between-subject Factors

# %% [markdown]
# ### Multilevel Conceptualisation

# %% [markdown]
# ## Including a `weights=` Structure in `lme()`

# %% [markdown]
# ## Model Comparisons

# %% [markdown]
# ## More on Pooling and Shrinkage
# ... In this part of the workshop, we will
