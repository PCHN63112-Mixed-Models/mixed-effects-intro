# %% [markdown]
# # The Mixed-effects Advantage
# ...Despite this, you may still be wondering *why* we would use mixed-effects models? They are clearly more complex than an approach such as GLS, so what is the justification?

# %% [markdown]
# ## Pooling and Shrinkage
# ...

# %% [markdown]
# ## Regularisation

# %% [markdown]
# ## When is GLS Enough?
