# %% [markdown]
# # Mixed-effects Models in `R`
# ...

# %% [markdown]
# ## The `lmer` Package
#
# ### Inference from `lme()`
# ... So this is very much in the "effective degrees of freedom" camp of solutions. However, the method used is not very sophisticated (as described in [Pinheiro & Bates (2000, p.91)](https://books.google.com/books?id=y54QDUTmvDcC&lpg=PR1&pg=PA91#v=onepage&q&f=false)).

# %% [markdown]
# ## The `lme4` Package
